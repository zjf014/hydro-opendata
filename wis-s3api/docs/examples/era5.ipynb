# %% [markdown]
# # 读取era5-land数据

# %%
from wis_s3api import era5
import numpy as np

# %%
start_time = np.datetime64('2021-01-01T01:00:00.000000000')
end_time = np.datetime64('2021-01-31T00:00:00.000000000')

# %% [markdown]
# ## 根据经纬度范围

# %%
bbox = (121,38,122,40)

# %%
ds = era5.open_dataset(['Total precipitation','10 metre U wind component'],start_time=start_time,end_time=end_time,bbox=bbox)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 720, lon: 11, lat: 21)
# Coordinates:
#   * lat      (lat) float32 38.0 38.1 38.2 38.3 38.4 ... 39.6 39.7 39.8 39.9 40.0
#   * lon      (lon) float32 121.0 121.1 121.2 121.3 ... 121.7 121.8 121.9 122.0
#   * time     (time) datetime64[ns] 2021-01-01T01:00:00 ... 2021-01-31
# Data variables:
#     tp       (time, lon, lat) float32 dask.array<chunksize=(23, 11, 21), meta=np.ndarray>
#     u10      (time, lon, lat) float32 dask.array<chunksize=(23, 11, 21), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-21 12:13:40 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %% [markdown]
# ## 根据矢量数据范围

# %%
shp = 'test.shp'

# %%
ds = era5.from_shp(['Total precipitation','10 metre U wind component'],start_time=start_time,end_time=end_time,shp=shp)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 720, lon: 4, lat: 3)
# Coordinates:
#   * lat      (lat) float32 49.6 49.7 49.8
#   * lon      (lon) float32 126.9 127.0 127.1 127.2
#   * time     (time) datetime64[ns] 2021-01-01T01:00:00 ... 2021-01-31
# Data variables:
#     tp       (time, lon, lat) float32 dask.array<chunksize=(23, 4, 3), meta=np.ndarray>
#     u10      (time, lon, lat) float32 dask.array<chunksize=(23, 4, 3), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-21 12:13:40 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %% [markdown]
# ### 生成nc文件

# %% [markdown]
# #### hourly

# %%
era5.to_netcdf(['Total precipitation','10 metre U wind component'],start_time=start_time,end_time=end_time,shp='test.shp',save_file='hourly.nc')
# Out:
# hourly.nc 已生成
# <xarray.Dataset>
# Dimensions:  (time: 720, lon: 4, lat: 3)
# Coordinates:
#   * lat      (lat) float32 49.6 49.7 49.8
#   * lon      (lon) float32 126.9 127.0 127.1 127.2
#   * time     (time) datetime64[ns] 2021-01-01T01:00:00 ... 2021-01-31
# Data variables:
#     tp       (time, lon, lat) float32 ...
#     u10      (time, lon, lat) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-21 12:13:40 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %% [markdown]
# #### daily

# %%
era5.to_netcdf(['Total precipitation','10 metre U wind component'],start_time=start_time,end_time=end_time,shp='test.shp',resolution='daily',save_file='daily.nc')
# Out:
# daily.nc 已生成
# <xarray.Dataset>
# Dimensions:  (time: 31, lat: 3, lon: 4)
# Coordinates:
#   * time     (time) datetime64[ns] 2021-01-01 2021-01-02 ... 2021-01-31
#   * lat      (lat) float32 49.6 49.7 49.8
#   * lon      (lon) float32 126.9 127.0 127.1 127.2
# Data variables:
#     tp       (time, lon, lat) float32 ...
#     u10      (time, lon, lat) float32 ...
# Attributes:
#     description:  var
#     history:      Created Fri Apr 14 01:41:55 2023
#     source:       netCDF4 python module tutorial

# %% [markdown]
# #### 6-hourly

# %%
era5.to_netcdf(['Total precipitation','10 metre U wind component'],start_time=start_time,end_time=end_time,shp='test.shp',resolution='6-hourly',save_file='6-hourly.nc')
# Out:
# 6-hourly.nc 已生成
# <xarray.Dataset>
# Dimensions:  (time: 124, lat: 3, lon: 4)
# Coordinates:
#   * time     (time) datetime64[ns] 2021-01-01T06:00:00 ... 2021-02-01
#   * lat      (lat) float32 49.6 49.7 49.8
#   * lon      (lon) float32 126.9 127.0 127.1 127.2
# Data variables:
#     tp       (time, lon, lat) float32 ...
#     u10      (time, lon, lat) float32 ...
# Attributes:
#     description:  var
#     history:      Created Fri Apr 14 01:41:57 2023
#     source:       netCDF4 python module tutorial
